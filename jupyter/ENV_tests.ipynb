# %%
import os
import sys
# https://jakevdp.github.io/blog/2017/12/05/installing-python-packages-from-jupyter/
# Install a conda package in the current Jupyter kernel
# !conda install --yes --quiet --prefix {sys.prefix} python-dotenv >>/dev/null
from dotenv import load_dotenv

# %%
home_dir = os.environ['HOME']
mends_dir =  home_dir + "/mends-on-fhir"
docker_compose_dir = mends_dir + "/docker-compose"
os.chdir(docker_compose_dir)
print(os.getcwd())
# Out:
# /home/mends/mends-on-fhir/docker-compose

# %%
load_dotenv()  # take environment variables from .env.
# Out:
# True

# %%
for k, v in os.environ.items():
    print(f'{k}={v}')
# Out:
# SHELL=/bin/bash
# HOSTNAME=59e3cfc92c16
# LANGUAGE=en_US.UTF-8
# NB_UID=502
# PWD=/home/mends
# GRANT_SUDO=yes
# HOME=/home/mends
# LANG=en_US.UTF-8
# NB_GID=20
# CHOWN_HOME=yes
# XDG_CACHE_HOME=/home/mends/.cache
# TERM=xterm-color
# CHOWN_HOME_OPTS=-R
# SHLVL=0
# CONDA_DIR=/opt/conda
# JUPYTER_PORT=8888
# NB_USER=mends
# LC_ALL=en_US.UTF-8
# PATH=/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin
# DEBIAN_FRONTEND=noninteractive
# LOGNAME=mends
# USER=mends
# SUDO_COMMAND=/opt/conda/bin/jupyter lab --IdentityProvider.token=
# SUDO_USER=root
# SUDO_UID=0
# SUDO_GID=0
# LD_LIBRARY_PATH=
# PYTHONPATH=
# PYDEVD_USE_FRAME_EVAL=NO
# JPY_SESSION_NAME=/home/mends/mends-on-fhir/jupyter/ENV_tests.ipynb
# JPY_PARENT_PID=49
# CLICOLOR=1
# FORCE_COLOR=1
# CLICOLOR_FORCE=1
# PAGER=cat
# GIT_PAGER=cat
# MPLBACKEND=module://matplotlib_inline.backend_inline
# HOST_MENDS_HOME=/Users/kahnmi/Documents/git/mends-on-fhir
# JUPYTER_MENDS_HOME=/user/mends/mends-on-fhir
# CONVERT_IMAGE=sessaid/whistle:latest
# CONVERT_INPUT=/Users/kahnmi/Documents/git/mends-on-fhir/input-examples/omop-fhir-data/synthea-cohort-020
# CONVERT_MAPPING_FUNCTIONS=/Users/kahnmi/Documents/git/mends-on-fhir/whistle-mappings/synthea/whistle-functions
# CONVERT_MAPPING_CONCEPT_MAPS=/Users/kahnmi/Documents/git/mends-on-fhir/whistle-mappings/synthea/concept-maps
# CONVERT_MAIN=/Users/kahnmi/Documents/git/mends-on-fhir/whistle-mappings/synthea/whistle-mains/main.wstl
# VALIDATE_IG=hl7.fhir.us.core#4.0.0
# PG_IMAGE=postgres:14.2-alpine
# PG_USER=postgres
# PG_PASSWORD=synthea
# PG_DATA=/data

# %%
# %%bash
# env | sort
# Out:
# CHOWN_HOME_OPTS=-R
# CHOWN_HOME=yes
# CLICOLOR=1
# CLICOLOR_FORCE=1
# CONDA_DIR=/opt/conda
# CONVERT_IMAGE=sessaid/whistle:latest
# CONVERT_INPUT=/Users/kahnmi/Documents/git/mends-on-fhir/input-examples/omop-fhir-data/synthea-cohort-020
# CONVERT_MAIN=/Users/kahnmi/Documents/git/mends-on-fhir/whistle-mappings/synthea/whistle-mains/main.wstl
# CONVERT_MAPPING_CONCEPT_MAPS=/Users/kahnmi/Documents/git/mends-on-fhir/whistle-mappings/synthea/concept-maps
# CONVERT_MAPPING_FUNCTIONS=/Users/kahnmi/Documents/git/mends-on-fhir/whistle-mappings/synthea/whistle-functions
# DEBIAN_FRONTEND=noninteractive
# FORCE_COLOR=1
# GIT_PAGER=cat
# GRANT_SUDO=yes
# HOME=/home/mends
# HOST_MENDS_HOME=/Users/kahnmi/Documents/git/mends-on-fhir
# HOSTNAME=59e3cfc92c16
# JPY_PARENT_PID=49
# JPY_SESSION_NAME=/home/mends/mends-on-fhir/jupyter/ENV_tests.ipynb
# JUPYTER_MENDS_HOME=/user/mends/mends-on-fhir
# JUPYTER_PORT=8888
# LANG=en_US.UTF-8
# LANGUAGE=en_US.UTF-8
# LC_ALL=en_US.UTF-8
# LD_LIBRARY_PATH=
# LOGNAME=mends
# MPLBACKEND=module://matplotlib_inline.backend_inline
# NB_GID=20
# NB_UID=502
# NB_USER=mends
# PAGER=cat
# PATH=/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin
# PG_DATA=/data
# PG_IMAGE=postgres:14.2-alpine
# PG_PASSWORD=synthea
# PG_USER=postgres
# PWD=/home/mends/mends-on-fhir/docker-compose
# PYDEVD_USE_FRAME_EVAL=NO
# PYTHONPATH=
# SHELL=/bin/bash
# SHLVL=0
# SUDO_COMMAND=/opt/conda/bin/jupyter lab --IdentityProvider.token=
# SUDO_GID=0
# SUDO_UID=0
# SUDO_USER=root
# TERM=xterm-color
# USER=mends
# _=/usr/bin/env
# VALIDATE_IG=hl7.fhir.us.core#4.0.0
# XDG_CACHE_HOME=/home/mends/.cache
